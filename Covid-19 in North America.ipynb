# %%
#import your libraries
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\Imtiaz\Downloads\Covid-19\covid_north_america.csv")

# %%
df.head()
# Out:
#          Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0             Anguilla          944           1.0              832
# 1  Antigua and Barbuda         4058         102.0             3726
# 2                Aruba        15925         171.0            15577
# 3              Bahamas        22351         643.0            21079
# 4             Barbados        17763         153.0            11506
#
#    Active Cases  Total Cases/1 mil population  Deaths/1 mil population  \
# 0           111                         62183                     66.0
# 1           230                         40987                   1030.0
# 2           177                        148320                   1593.0
# 3           629                         56124                   1615.0
# 4          6104                         61711                    532.0
#
#    Total Tests  Tests/1 mil population  Population
# 0      47917.0               3156380.0       15181
# ...

# %%
df.tail()
# Out:
#              Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 33               St. Barth         1589           6.0              462
# 34  St. Vincent Grenadines         4995          68.0             3108
# 35     Trinidad and Tobago        57329        1696.0            50732
# 36        Turks and Caicos         2980          23.0             2902
# 37                     USA     46823938      766299.0         36715313
#
#     Active Cases  Total Cases/1 mil population  Deaths/1 mil population  \
# 33          1121                        160230                    605.0
# 34          1819                         44835                    610.0
# 35          4901                         40788                   1207.0
# 36            55                         75610                    584.0
# 37       9342326                        140366                   2297.0
#
#     Total Tests  Tests/1 mil population  Population
# 33      38369.0               3869013.0        9917
# ...

# %%
df.describe()
# Out:
#         Total Cases   Total Deaths  Total Recovered  Active Cases  \
# count  3.800000e+01      37.000000     3.800000e+01  3.800000e+01
# mean   1.480208e+06   31031.297297     1.181240e+06  2.687535e+05
# std    7.585157e+06  132928.839813     5.949429e+06  1.513258e+06
# min    4.100000e+01       1.000000     3.400000e+01  6.000000e+00
# 25%    3.918500e+03      56.000000     2.545500e+03  1.260000e+02
# 50%    1.675300e+04     207.000000     8.512500e+03  2.061500e+03
# 75%    1.073200e+05    3629.000000     8.571100e+04  1.060175e+04
# max    4.682394e+07  766299.000000     3.671531e+07  9.342326e+06
#
#        Total Cases/1 mil population  Deaths/1 mil population   Total Tests  \
# count                     38.000000                37.000000  3.700000e+01
# mean                   66769.921053              1007.891892  2.123956e+07
# std                    41768.641901               628.590477  1.147321e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country/Other                 38 non-null     object
#  1   Total Cases                   38 non-null     int64
#  2   Total Deaths                  37 non-null     float64
#  3   Total Recovered               38 non-null     int64
#  4   Active Cases                  38 non-null     int64
#  5   Total Cases/1 mil population  38 non-null     int64
#  6   Deaths/1 mil population       37 non-null     float64
#  7   Total Tests                   37 non-null     float64
#  8   Tests/1 mil population        37 non-null     float64
#  9   Population                    38 non-null     int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (38, 10)

# %%
#Top 10 countries in total deaths and total cases.

# %%
top_5 = df.sort_values(by=['Total Deaths'], ascending = False).reset_index()

# %%
top_5.head()
# Out:
#    index Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0     37           USA     46823938      766299.0         36715313
# 1     25        Mexico      3807211      288365.0          3168911
# 2      8        Canada      1714414       28968.0          1659368
# 3     20     Guatemala       601572       15094.0           580691
# 4     22      Honduras       375381       10240.0           115886
#
#    Active Cases  Total Cases/1 mil population  Deaths/1 mil population  \
# 0       9342326                        140366                   2297.0
# 1        349935                         29122                   2206.0
# 2         26078                         44901                    759.0
# 3          5787                         32773                    822.0
# 4        249255                         37115                   1012.0
#
#    Total Tests  Tests/1 mil population  Population
# 0  698692194.0               2094493.0   333585423
# ...

# %%
sns.barplot(x=top_5.head()['Total Deaths'],y=top_5.head()['Country/Other'],color='red',label='Total Deaths')
# Out:
# <AxesSubplot:xlabel='Total Deaths', ylabel='Country/Other'>

# %%
top_4 = df.sort_values(by=['Active Cases'], ascending = False).reset_index()

# %%
top_4.head()
# Out:
#    index Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0     37           USA     46823938      766299.0         36715313
# 1     25        Mexico      3807211      288365.0          3168911
# 2     22      Honduras       375381       10240.0           115886
# 3     11    Costa Rica       559698        7029.0           500425
# 4     19    Guadeloupe        54537         742.0             2250
#
#    Active Cases  Total Cases/1 mil population  Deaths/1 mil population  \
# 0       9342326                        140366                   2297.0
# 1        349935                         29122                   2206.0
# 2        249255                         37115                   1012.0
# 3         52244                        108553                   1363.0
# 4         51545                        136269                   1854.0
#
#    Total Tests  Tests/1 mil population  Population
# 0  698692194.0               2094493.0   333585423
# ...

# %%
sns.barplot(x=top_5.head()['Active Cases'],y=top_5.head()['Country/Other'],color='red',label='Active Cases')
# Out:
# <AxesSubplot:xlabel='Active Cases', ylabel='Country/Other'>

# %%
#Correlation matrix between various numeric columns.
df.corr(method = 'pearson')
# Out:
#                               Total Cases  Total Deaths  Total Recovered  \
# Total Cases                      1.000000      0.960148         0.999917
# Total Deaths                     0.960148      1.000000         0.961282
# Total Recovered                  0.999917      0.961282         1.000000
# Active Cases                     0.998000      0.946687         0.997156
# Total Cases/1 mil population     0.279390      0.215990         0.278383
# Deaths/1 mil population          0.370225      0.440476         0.370555
# Total Tests                      0.997321      0.939472         0.997151
# Tests/1 mil population           0.061864      0.023459         0.060744
# Population                       0.953829      0.996045         0.955730
#
#                               Active Cases  Total Cases/1 mil population  \
# Total Cases                       0.998000                      0.279390
# Total Deaths                      0.946687                      0.215990
# ...

# %%
sns.heatmap(df.corr(),annot = True)
plt.show()
